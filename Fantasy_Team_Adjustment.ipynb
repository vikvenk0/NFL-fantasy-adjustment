# %%
import pandas as pd

# %%
# %%capture
pip install qgrid

# %%
#fantasy data for all regular season weeks
weekly_data = pd.read_csv("weekly_test.csv")

# %%
#df for every year week position with def team
grouped_data = (
    weekly_data.groupby(['year', 'week', 'posteam', 'defteam', 'position'], as_index=False)
    .agg({'half_ppr': 'sum'})
)

# %%
# Step 1: Aggregate total sum and count by year, posteam, and position
total_agg = (
    grouped_data.groupby(['year', 'posteam', 'position'], as_index=False)
    .agg(total_half_ppr=('half_ppr', 'sum'), count=('half_ppr', 'count'))
)

# %%
# Step 2: Merge total_agg back into the original grouped_data
grouped_data = grouped_data.merge(
    total_agg, 
    on=['year', 'posteam', 'position'], 
    how='left'
)

# %%
# Step 3: Calculate leave-one-out average
grouped_data['team_position_avg'] = (
    (grouped_data['total_half_ppr'] - grouped_data['half_ppr']) /
    (grouped_data['count'] - 1)
)
# Step 4: Drop intermediate columns if needed
grouped_data.drop(columns=['total_half_ppr', 'count'], inplace=True)

# %%
grouped_data['adjustment'] = grouped_data['half_ppr'] - grouped_data['team_position_avg']

# %%
adjustment_avg = (
    grouped_data.groupby(['year', 'defteam', 'position'], as_index=False)
    .agg(avg_adjustment=('adjustment', 'mean'))
)

# %%
adjustment_avg
# Out:
#       year defteam position  avg_adjustment
# 0     2003     ARI       QB        4.563084
# 1     2003     ARI       RB       -0.049500
# 2     2003     ARI       TE       -0.591889
# 3     2003     ARI       WR        2.831583
# 4     2003     ATL       QB        2.453000
# ...    ...     ...      ...             ...
# 2811  2024     TEN       WR       -5.639933
# 2812  2024     WAS       QB       -1.123111
# 2813  2024     WAS       RB        1.959597
# 2814  2024     WAS       TE       -0.135861
# 2815  2024     WAS       WR        0.597172
#
# [2816 rows x 4 columns]

# %%
adjustment_avg_2024 = adjustment_avg[adjustment_avg['year'] == 2024]

# %%
# Pivot the table to show `defteam` as rows, `position` as columns, and `avg_adjustment` as values
pivot_table_2024 = adjustment_avg_2024.pivot(index='defteam', columns='position', values='avg_adjustment')
pivot_table_2024 = pivot_table_2024.sort_index()

# %%
def color_map(val):
    if pd.notnull(val):  # Check for non-NaN values
        # Normalize the value between 0 and 1
        norm_val = (val - pivot_table_2024.min().min()) / (pivot_table_2024.max().max() - pivot_table_2024.min().min())
        # Map normalized value to blue-green gradient
        blue = int(255 * (1 - norm_val))  # Higher values reduce blue
        green = int(255 * norm_val)  # Higher values increase green
        return f'background-color: rgb(0, {green}, {blue})'  # Use only green and blue channels
    return ''  # Leave NaN values uncolored

# %%
styled_table = pivot_table_2024.style.map(color_map)

# %%
styled_table
# Out:
# <style type="text/css">
# #T_b637a_row0_col0, #T_b637a_row30_col1 {
#   background-color: rgb(0, 108, 146);
# }
# #T_b637a_row0_col1 {
#   background-color: rgb(0, 114, 140);
# }
# #T_b637a_row0_col2, #T_b637a_row4_col3, #T_b637a_row15_col0 {
#   background-color: rgb(0, 104, 150);
# }
# #T_b637a_row0_col3, #T_b637a_row2_col1, #T_b637a_row9_col1, #T_b637a_row31_col0 {
#   background-color: rgb(0, 106, 148);
# }
# #T_b637a_row1_col0, #T_b637a_row8_col0 {
#   background-color: rgb(0, 154, 100);
# }
# #T_b637a_row1_col1, #T_b637a_row3_col0, #T_b637a_row23_col3 {
#   background-color: rgb(0, 93, 161);
# }
# #T_b637a_row1_col2, #T_b637a_row16_col0, #T_b637a_row17_col0, #T_b637a_row24_col0 {
#   background-color: rgb(0, 122, 132);
# }
# #T_b637a_row1_col3, #T_b637a_row29_col0 {
#   background-color: rgb(0, 196, 58);
# }
# #T_b637a_row2_col0, #T_b637a_row29_col3 {
#   background-color: rgb(0, 166, 88);
# }
# #T_b637a_row2_col2, #T_b637a_row12_col0 {
#   background-color: rgb(0, 127, 127);
# }
# #T_b637a_row2_col3 {
#   background-color: rgb(0, 248, 6);
# }
# #T_b637a_row3_col1 {
#   background-color: rgb(0, 161, 93);
# }
# #T_b637a_row3_col2, #T_b637a_row22_col0 {
#   background-color: rgb(0, 111, 143);
# }
# #T_b637a_row3_col3 {
#   background-color: rgb(0, 100, 154);
# }
# #T_b637a_row4_col0, #T_b637a_row19_col1 {
#   background-color: rgb(0, 163, 91);
# }
# #T_b637a_row4_col1 {
#   background-color: rgb(0, 255, 0);
# }
# #T_b637a_row4_col2 {
#   background-color: rgb(0, 178, 76);
# }
# #T_b637a_row5_col0, #T_b637a_row12_col1, #T_b637a_row28_col3 {
#   background-color: rgb(0, 67, 187);
# }
# #T_b637a_row5_col1, #T_b637a_row11_col2, #T_b637a_row31_col1 {
#   background-color: rgb(0, 148, 106);
# }
# #T_b637a_row5_col2, #T_b637a_row8_col3, #T_b637a_row20_col2, #T_b637a_row21_col2, #T_b637a_row26_col2 {
#   background-color: rgb(0, 123, 131);
# }
# #T_b637a_row5_col3 {
#   background-color: rgb(0, 52, 202);
# }
# #T_b637a_row6_col0, #T_b637a_row22_col1 {
#   background-color: rgb(0, 176, 78);
# }
# #T_b637a_row6_col1 {
#   background-color: rgb(0, 96, 158);
# }
# #T_b637a_row6_col2, #T_b637a_row21_col1 {
#   background-color: rgb(0, 153, 101);
# }
# #T_b637a_row6_col3 {
#   background-color: rgb(0, 167, 87);
# }
# #T_b637a_row7_col0, #T_b637a_row26_col1 {
#   background-color: rgb(0, 113, 141);
# }
# #T_b637a_row7_col1 {
#   background-color: rgb(0, 82, 172);
# }
# #T_b637a_row7_col2 {
#   background-color: rgb(0, 130, 124);
# }
# #T_b637a_row7_col3 {
#   background-color: rgb(0, 175, 79);
# }
# #T_b637a_row8_col1 {
#   background-color: rgb(0, 179, 75);
# }
# #T_b637a_row8_col2 {
#   background-color: rgb(0, 98, 156);
# }
# #T_b637a_row9_col0, #T_b637a_row19_col0, #T_b637a_row25_col1, #T_b637a_row25_col2 {
#   background-color: rgb(0, 74, 180);
# }
# #T_b637a_row9_col2 {
#   background-color: rgb(0, 87, 167);
# }
# #T_b637a_row9_col3 {
#   background-color: rgb(0, 45, 209);
# }
# #T_b637a_row10_col0 {
#   background-color: rgb(0, 83, 171);
# }
# #T_b637a_row10_col1, #T_b637a_row26_col3 {
#   background-color: rgb(0, 62, 192);
# }
# #T_b637a_row10_col2 {
#   background-color: rgb(0, 81, 173);
# }
# #T_b637a_row10_col3 {
#   background-color: rgb(0, 139, 115);
# }
# #T_b637a_row11_col0 {
#   background-color: rgb(0, 94, 160);
# }
# #T_b637a_row11_col1, #T_b637a_row31_col2 {
#   background-color: rgb(0, 119, 135);
# }
# #T_b637a_row11_col3, #T_b637a_row24_col3 {
#   background-color: rgb(0, 85, 169);
# }
# #T_b637a_row12_col2, #T_b637a_row20_col0 {
#   background-color: rgb(0, 102, 152);
# }
# #T_b637a_row12_col3 {
#   background-color: rgb(0, 157, 97);
# }
# #T_b637a_row13_col0 {
#   background-color: rgb(0, 147, 107);
# }
# #T_b637a_row13_col1 {
#   background-color: rgb(0, 136, 118);
# }
# #T_b637a_row13_col2, #T_b637a_row16_col3 {
#   background-color: rgb(0, 172, 82);
# }
# #T_b637a_row13_col3, #T_b637a_row27_col1 {
#   background-color: rgb(0, 134, 120);
# }
# #T_b637a_row14_col0 {
#   background-color: rgb(0, 221, 33);
# }
# #T_b637a_row14_col1 {
#   background-color: rgb(0, 195, 59);
# }
# #T_b637a_row14_col2 {
#   background-color: rgb(0, 162, 92);
# }
# #T_b637a_row14_col3 {
#   background-color: rgb(0, 217, 37);
# }
# #T_b637a_row15_col1 {
#   background-color: rgb(0, 0, 255);
# }
# #T_b637a_row15_col2 {
#   background-color: rgb(0, 142, 112);
# }
# #T_b637a_row15_col3 {
#   background-color: rgb(0, 84, 170);
# }
# #T_b637a_row16_col1 {
#   background-color: rgb(0, 95, 159);
# }
# #T_b637a_row16_col2 {
#   background-color: rgb(0, 135, 119);
# }
# #T_b637a_row17_col1, #T_b637a_row23_col2 {
#   background-color: rgb(0, 71, 183);
# }
# #T_b637a_row17_col2 {
#   background-color: rgb(0, 73, 181);
# }
# #T_b637a_row17_col3, #T_b637a_row29_col2 {
#   background-color: rgb(0, 146, 108);
# }
# #T_b637a_row18_col0 {
#   background-color: rgb(0, 149, 105);
# }
# #T_b637a_row18_col1 {
#   background-color: rgb(0, 171, 83);
# }
# #T_b637a_row18_col2 {
#   background-color: rgb(0, 186, 68);
# }
# #T_b637a_row18_col3 {
#   background-color: rgb(0, 60, 194);
# }
# #T_b637a_row19_col2 {
#   background-color: rgb(0, 121, 133);
# }
# #T_b637a_row19_col3 {
#   background-color: rgb(0, 64, 190);
# }
# #T_b637a_row20_col1 {
#   background-color: rgb(0, 43, 211);
# }
# #T_b637a_row20_col3 {
#   background-color: rgb(0, 173, 81);
# }
# #T_b637a_row21_col0, #T_b637a_row27_col2 {
#   background-color: rgb(0, 125, 129);
# }
# #T_b637a_row21_col3 {
#   background-color: rgb(0, 131, 123);
# }
# #T_b637a_row22_col2 {
#   background-color: rgb(0, 133, 121);
# }
# #T_b637a_row22_col3 {
#   background-color: rgb(0, 152, 102);
# }
# #T_b637a_row23_col0 {
#   background-color: rgb(0, 115, 139);
# }
# #T_b637a_row23_col1, #T_b637a_row30_col0 {
#   background-color: rgb(0, 137, 117);
# }
# #T_b637a_row24_col1, #T_b637a_row29_col1 {
#   background-color: rgb(0, 117, 137);
# }
# #T_b637a_row24_col2, #T_b637a_row28_col2 {
#   background-color: rgb(0, 90, 164);
# }
# #T_b637a_row25_col0 {
#   background-color: rgb(0, 65, 189);
# }
# #T_b637a_row25_col3 {
#   background-color: rgb(0, 36, 218);
# }
# #T_b637a_row26_col0 {
#   background-color: rgb(0, 51, 203);
# }
# #T_b637a_row27_col0, #T_b637a_row28_col1, #T_b637a_row31_col3 {
#   background-color: rgb(0, 129, 125);
# }
# #T_b637a_row27_col3 {
#   background-color: rgb(0, 132, 122);
# }
# #T_b637a_row28_col0 {
#   background-color: rgb(0, 92, 162);
# }
# #T_b637a_row30_col2 {
#   background-color: rgb(0, 99, 155);
# }
# #T_b637a_row30_col3 {
#   background-color: rgb(0, 44, 210);
# }
# </style>
# <table id="T_b637a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >position</th>
#       <th id="T_b637a_level0_col0" class="col_heading level0 col0" >QB</th>
#       <th id="T_b637a_level0_col1" class="col_heading level0 col1" >RB</th>
#       <th id="T_b637a_level0_col2" class="col_heading level0 col2" >TE</th>
#       <th id="T_b637a_level0_col3" class="col_heading level0 col3" >WR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >defteam</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b637a_level0_row0" class="row_heading level0 row0" >ARI</th>
#       <td id="T_b637a_row0_col0" class="data row0 col0" >-0.973844</td>
#       <td id="T_b637a_row0_col1" class="data row0 col1" >-0.540000</td>
#       <td id="T_b637a_row0_col2" class="data row0 col2" >-1.234444</td>
#       <td id="T_b637a_row0_col3" class="data row0 col3" >-1.092778</td>
#     </tr>
#     <tr>
#       <th id="T_b637a_level0_row1" class="row_heading level0 row1" >ATL</th>
#       <td id="T_b637a_row1_col0" class="data row1 col0" >2.397474</td>
#       <td id="T_b637a_row1_col1" class="data row1 col1" >-2.080707</td>
#       <td id="T_b637a_row1_col2" class="data row1 col2" >0.030788</td>
#       <td id="T_b637a_row1_col3" class="data row1 col3" >5.451515</td>
#     </tr>
#     <tr>
#       <th id="T_b637a_level0_row2" class="row_heading level0 row2" >BAL</th>
#       <td id="T_b637a_row2_col0" class="data row2 col0" >3.228627</td>
#       <td id="T_b637a_row2_col1" class="data row2 col1" >-1.072222</td>
#       <td id="T_b637a_row2_col2" class="data row2 col2" >0.398384</td>
#       <td id="T_b637a_row2_col3" class="data row2 col3" >9.263758</td>
#     </tr>
#     <tr>
#       <th id="T_b637a_level0_row3" class="row_heading level0 row3" >BUF</th>
#       <td id="T_b637a_row3_col0" class="data row3 col0" >-2.019959</td>

# %%
# Export the styled table as an HTML file
html_table = styled_table.to_html()  # Use to_html instead of render()
with open("styled_table.html", "w") as file:
    file.write(html_table)
